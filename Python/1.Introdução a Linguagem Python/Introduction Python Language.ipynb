# %%
FIRST STEPS IN PYTHON
Let`s get to know the power of this programming language.

print("hello world!")
hello world!

Programmer lengend has it that if you don't print "hello world" when
start learning a programming language, you won't be able to
learn nothing of the language in question. Myth
or truth? Just in case, this was our first line of command, from
many that we will learn in this discipline. As you can see, a command of
"clean" syntax, no semicolon, no square brackets, no library import
is the essence of the Python programming language, which was created to have
Simple commands and structures that are easy to read and understand.

Python was created in the early 1990s by Guido van Rossum at Stichting 
Mathematisch Centrum (CWI), in the Netherlands, as a successor to a 
call ABC. Guido is the main author of Python, although there are many 
contributions grom other researchers (Python Reference Manual, 2020). Guido
passed through other institutuions, such as the CNRI, in 1995, in Virginía (Corporation for
National Research Initiatives) and at BeOpen in 2000, where he formed BeOpen
PythonLabs. In October of the same year, the PythonLabs team moved to
Digital Creations (now Zope Corporation). In 2001, the Python Software Foundation
(PSF) was formed, a non-profit organization created specifically to own
the ontellectial property related to Python.

WHY USE PYTHON?

According to the Python Beginners Development Guide (Beginners Guide 
Overview). Python is an object-oriented, clear and 
powerfil, comparable to Perl, Ruby, Scheme or Java. We can highlight some 
characteristics that make this language remarkable:
    
    It use an elegant syntax, making the programs you
    he writes.
    
    It is an easy-to-use language, which makes Python ideal for 
    prototype development and other ad-hoc programming task, without
    compromise maintenance.
    
    It comes with a large standard library that supports many common
    programming, such as connecting to web servers, searching text with
    regular expressions, read and modify files.
    
    it has numerous libraries that extend its acting power. It is an
    interpreted language, that is, once the code is written, it is not
    needs to be converted into machine language by process of 
    compilation.
    
    Allows multiple attriburion. We can assing values to more than one variable
    in a single instruction. For example, a,b = 2,3.
    
One of the grat features of the language is its syntax. One of the main
Guido's idea is that code is read much more often than it is
written (PEP 9 - Style Guide for Python Code). This aspect is so important that a 
code that follows the rules of the python language is called "pythonic code". These
rules are defined by PEP 8 (Python Enhancement Proposal) and concern
formatting, identation, parameters in functions and anything else that might be
related to code syntax.

Python has proven to be a very powerful language and is being widely
adopted by professionals in the data area.

The Python 3 interpreter uses unicode by defalt, which makes it possible to use
variable names with accents and even other special characters, but it is not a 
good practice. Such flexibility shows why the language has been adopted by 
people who are not in the exact area, as the reading is closer to the 
human rather than machine interpretation

WHERE TO PROGRAM

Now that we know a little about this important language and we already know that
there is even a writing "code" determined by PEP 8, we can as ourselves:
but where do I write the codes in Python and see the results? The implementation
Python code can be done either in tools installed on your
computer and in cloud environments. In this universe of possibilities, the
first point you need to understand is that in order to get the results of a
code, we need to have a Python interpreter. Lets start by analyzing the 
options that can be installed.

INSTALLING PYTHON INTERPRETER

On the officioal language page (https://www.python.org/downloads/), we can
find the various versions of the pure Python interpreter (no libraries of 
third parties), available for various operating systems. To install, just
choose the operating system, download the most current version of
3.X interpreter and, after the download is complete, click on the executable file that
was downloaded from the official repository.

In the Python interpreter installation process, you need to check the Add option
Python 3.X to PATH. By checking this option, the Path environment variable
is configured to understand the "python" command. IF the option is not checked,
you will need to configure it manually later.

When completing the interpreter installation, if you checked the option "Add Python 3.X
to PATH", we can now star programming through interative mode. For this,
open the Windowns command prompt and type "python" after open
the inrative mode, we can already  type python commands and, by pressing "enter", the
command is immediately interpreted and the result is displayed.

If you don't want to navigat to the command prompt, you can also use
IDLE application, already pre-installed on Windowns.

IDE'S PYCHARM E VISUAL STUDIO CODE

Using interative mode is very simple and recommended for quick tests,
however this form of implementation is not applicable when we need to creat a 
code that will be executed more than once. This happens beacuse in the mode 
iteratively, when closing the prompt, all code lost.

For solution implementation (and not just quick test), we
programmers use an IDE, (Integrated Development Environment) that
translating means Integrated Development Enviroment this kind of software
has a series of tools that help development, such as inte
